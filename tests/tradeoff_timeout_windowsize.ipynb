# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv('results_hs.csv')

# %%
df = df.sort_values(by=['t_mean'])
df
# Out:
#     Unnamed: 0      TimeOut  MaxInQueue        t1        t2        t3  \
# 9            9   266.666667       100.0  1.004593  1.004340  1.104459
# 4            4    50.000000       100.0  1.103909  1.106824  1.003534
# 3            3    50.000000        80.0  1.204175  1.204464  1.103908
# 14          14   483.333333       100.0  1.104916  1.104151  1.304415
# 19          19   700.000000       100.0  1.205562  1.205338  1.104363
# 2            2    50.000000        60.0  1.204430  1.204263  1.204394
# 24          24   916.666667       100.0  1.105355  1.305883  1.505746
# 8            8   266.666667        80.0  1.305691  1.406492  1.405485
# 38          38  1566.666667        80.0  1.406238  1.409694  1.405808
# 34          34  1350.000000       100.0  1.907281  1.305467  1.104609
# 13          13   483.333333        80.0  1.406174  1.405759  1.506688
# 1            1    50.000000        40.0  1.505428  1.506113  1.404882
# ...

# %%
df.plot(x='MaxInQueue', y='t_mean', style='o')

# %%
df.plot(x='TimeOut', y='t_mean', style='o')
