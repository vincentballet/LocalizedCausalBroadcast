# %%
import numpy as np
from tqdm import tqdm
# %matplotlib inline
from matplotlib import pyplot as plt
import pickle

# %% [markdown]
# ## Variable number of processes

# %%
# repetitions
repetitions = range(5)

# n processes
ns = list(range(2, 7))

# messages
m = 500

# %%
results = pickle.loads(open('results_n.pkl', 'rb').read())

# %%
xvals = ns
yvals_means = np.array([np.mean(results[n]) for n in ns])
yvals_stds  = [np.std(results[n]) for n in ns]

# %%
# fitting a polynomial with deg 2
p = np.polyfit(xvals, yvals_means, deg = 2)
poly_vals = [p[0] * x ** 2 + p[1] * x + p[2] for x in xvals]

# %%
plt.figure()
plt.xlabel('n')
plt.ylabel('Time, sec')
plt.title('URB for m=%d and different n' % m)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.plot(xvals, poly_vals, label = 'Deg 2 regression')
plt.legend()
#plt.yscale('log')
plt.show()

# %% [markdown]
# ## Variable number of messages

# %%
# repetitions
repetitions = range(5)

# n processes
n = 5

# messages
ms = np.arange(500, 1000, 50)

# %%
results = pickle.loads(open('results_m.pkl', 'rb').read())

# %%
xvals = ms
yvals_means = np.array([np.mean(results[m]) for m in ms])
yvals_stds  = [np.std(results[m]) for m in ms]

# %%
plt.figure()
plt.xlabel('m')
plt.ylabel('Time, sec')
plt.title('URB for n=%d and different m' % n)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.legend()
#plt.yscale('log')
plt.show()

# %% [markdown]
# ## Variable number of messages: bigger numbers

# %%
# repetitions
repetitions = range(5)

# n processes
n = 3

# messages
ms = np.arange(1000, 10000, 1000)

# %%
results = pickle.loads(open('results_m_bigger.pkl', 'rb').read())

# %%
xvals = ms
yvals_means = np.array([np.mean(results[m]) for m in ms])
yvals_stds  = [np.std(results[m]) for m in ms]

# %%
plt.figure()
plt.xlabel('m')
plt.ylabel('Time, sec')
plt.title('URB for n=%d and different m' % n)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.legend()
#plt.yscale('log')
plt.show()

# %% [markdown]
# ### BestEffortBroadcast profiling

# %%
# repetitions
repetitions = range(5)

# n processes
n = 3

# messages
ms = np.arange(1, 2000000, 500000)

# %%
results = pickle.loads(open('results_m_beb.pkl', 'rb').read())

# %%
xvals = ms
yvals_means = np.array([np.mean(results[m]) for m in ms])
yvals_stds  = [np.std(results[m]) for m in ms]

# %%
plt.figure()
plt.xlabel('m')
plt.ylabel('Time, sec')
plt.title('BEB for n=%d and different m' % n)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.legend()
#plt.yscale('log')
plt.show()

# %% [markdown]
# ### FIFOBroadcast profiling

# %%
# repetitions
repetitions = range(5)

# n processes
n = 3

# messages
ms = np.arange(1, 50000, 5000)

# %%
results = pickle.loads(open('results_m_fifo.pkl', 'rb').read())

# %%
xvals = ms
yvals_means = np.array([np.mean(results[m]) for m in ms])
yvals_stds  = [np.std(results[m]) for m in ms]

# %%
plt.figure()
plt.xlabel('m')
plt.ylabel('Time, sec')
plt.title('FIFO for n=%d and different m' % n)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.legend()
#plt.yscale('log')
plt.show()

# %% [markdown]
# ### URB profiling

# %%
# repetitions
repetitions = range(5)

# n processes
n = 3

# messages
ms = np.arange(1, 100000, 15000)

# %%
results = pickle.loads(open('results_m_urb.pkl', 'rb').read())

# %%
xvals = ms
yvals_means = np.array([np.mean(results[m]) for m in ms])
yvals_stds  = [np.std(results[m]) for m in ms]

# %%
plt.figure()
plt.xlabel('m')
plt.ylabel('Time, sec')
plt.title('URB for n=%d and different m' % n)
plt.plot(xvals, yvals_means, label = 'mean')
plt.fill_between(xvals, yvals_means - yvals_stds, yvals_means + yvals_stds, alpha = 0.5, label = 'std')
plt.legend()
#plt.yscale('log')
plt.show()
