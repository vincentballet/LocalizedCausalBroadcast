# %%
import os
import numpy as np
import itertools
import time
from subprocess import call
import pandas as pd
import subprocess

# %%
def generate_perfectlinkh(t, m):
    with open("perfectlink_backup.h", "r") as b, open("perfectlink.h", "w") as f:
        for line in b:
            if 'TIMEOUT_MSG' in line:
                f.write('    static unsigned const TIMEOUT_MSG = {};\n'.format(t))
            elif 'MAX_IN_QUEUE' in line:
                f.write('    static unsigned const MAX_IN_QUEUE = {};\n'.format(m))
            else :
                f.write(line)

# %%
timeouts = np.linspace(50, 2000, 10)
maxinqueues = np.linspace(20, 100, 5)
# timeouts = [500, 1000]
# maxinqueues = [50]
m = 20
n = 3
runs = 3
run_times = []
columns = ['TimeOut', 'MaxInQueue', 't1', 't2', 't3', 't_mean']
df = pd.DataFrame(columns=columns)
tot_runs = len(timeouts) * len(maxinqueues)

# %%
for idx, x in enumerate(itertools.product(timeouts, maxinqueues)):
    print("{}/{} Running for TimeOut={}, MaxInQueue={}".format(idx+1, tot_runs, x[0], x[1])) 
    generate_perfectlinkh(x[0], x[1])
    run_times = []
    for i in range(runs):
        print("\tRun " + str(i))
        call(["make"])
        call(["python", "tests/run_performance.py", ".", str(m), str(n)])
        with open("time.out", "r") as f:
            run_times.append(float(f.readline()))
    df.loc[idx] = [x[0], x[1], run_times[0], run_times[1], run_times[2], np.mean(run_times)]
# Out:
# 1/50 Running for TimeOut=50.0, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 2/50 Running for TimeOut=50.0, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 3/50 Running for TimeOut=50.0, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 4/50 Running for TimeOut=50.0, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 5/50 Running for TimeOut=50.0, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 6/50 Running for TimeOut=266.66666666666663, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 7/50 Running for TimeOut=266.66666666666663, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 8/50 Running for TimeOut=266.66666666666663, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 9/50 Running for TimeOut=266.66666666666663, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 10/50 Running for TimeOut=266.66666666666663, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 11/50 Running for TimeOut=483.3333333333333, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 12/50 Running for TimeOut=483.3333333333333, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 13/50 Running for TimeOut=483.3333333333333, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 14/50 Running for TimeOut=483.3333333333333, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 15/50 Running for TimeOut=483.3333333333333, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 16/50 Running for TimeOut=700.0, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 17/50 Running for TimeOut=700.0, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 18/50 Running for TimeOut=700.0, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 19/50 Running for TimeOut=700.0, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 20/50 Running for TimeOut=700.0, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 21/50 Running for TimeOut=916.6666666666666, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 22/50 Running for TimeOut=916.6666666666666, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 23/50 Running for TimeOut=916.6666666666666, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 24/50 Running for TimeOut=916.6666666666666, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 25/50 Running for TimeOut=916.6666666666666, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 26/50 Running for TimeOut=1133.3333333333333, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 27/50 Running for TimeOut=1133.3333333333333, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 28/50 Running for TimeOut=1133.3333333333333, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 29/50 Running for TimeOut=1133.3333333333333, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 30/50 Running for TimeOut=1133.3333333333333, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 31/50 Running for TimeOut=1350.0, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 32/50 Running for TimeOut=1350.0, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 33/50 Running for TimeOut=1350.0, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 34/50 Running for TimeOut=1350.0, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 35/50 Running for TimeOut=1350.0, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 36/50 Running for TimeOut=1566.6666666666665, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 37/50 Running for TimeOut=1566.6666666666665, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 38/50 Running for TimeOut=1566.6666666666665, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 39/50 Running for TimeOut=1566.6666666666665, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 40/50 Running for TimeOut=1566.6666666666665, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 41/50 Running for TimeOut=1783.3333333333333, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 42/50 Running for TimeOut=1783.3333333333333, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 43/50 Running for TimeOut=1783.3333333333333, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 44/50 Running for TimeOut=1783.3333333333333, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 45/50 Running for TimeOut=1783.3333333333333, MaxInQueue=100.0
# 	Run 0
# 	Run 1
# 	Run 2
# 46/50 Running for TimeOut=2000.0, MaxInQueue=20.0
# 	Run 0
# 	Run 1
# 	Run 2
# 47/50 Running for TimeOut=2000.0, MaxInQueue=40.0
# 	Run 0
# 	Run 1
# 	Run 2
# 48/50 Running for TimeOut=2000.0, MaxInQueue=60.0
# 	Run 0
# 	Run 1
# 	Run 2
# 49/50 Running for TimeOut=2000.0, MaxInQueue=80.0
# 	Run 0
# 	Run 1
# 	Run 2
# 50/50 Running for TimeOut=2000.0, MaxInQueue=100.0
# 	Run 0
# 	Run 1
